# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

data = pd.read_csv('workerhours.csv')

# %%
data = pd.read_csv('workerhours.csv')

# %%
data.plot(x="Year", y="Hours", kind="line")
